# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('D:\arabica_ratings_raw.csv',encoding='latin-1')
df.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-31-cebc2065cac9> in <module>
# ----> 1 df=pd.read_csv('D:\arabica_ratings_raw.csv',encoding='latin-1')
#       2 df.head()
#
# ~\Downloads\geop2\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\Downloads\geop2\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\Downloads\geop2\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~\Downloads\geop2\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~\Downloads\geop2\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1989         if kwds.get("compression") is None and encoding:
#    1990             if isinstance(src, str):
# -> 1991                 src = open(src, "rb")
#    1992                 self.handles.append(src)
#    1993
#
# OSError: [Errno 22] Invalid argument: 'D:\x07rabica_ratings_raw.csv'

# %%
df=pd.read_csv('d:\\arabica_ratings_raw.csv',encoding='latin-1')
df.head()
# Out:
#    Unnamed: 0  quality_score  view_certificate_1  view_certificate_2  \
# 0           0          90.58                 NaN                 NaN
# 1           1          89.92                 NaN                 NaN
# 2           2          89.75                 NaN                 NaN
# 3           3          89.00                 NaN                 NaN
# 4           4          88.83                 NaN                 NaN
#
#    Cupping Protocol and Descriptors  View Green Analysis Details  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#    Request a Sample  Species                     Owner Country of Origin  ...  \
# 0               NaN  Arabica                 metad plc          Ethiopia  ...
# 1               NaN  Arabica                 metad plc          Ethiopia  ...
# 2               NaN  Arabica  Grounds for Health Admin         Guatemala  ...
# 3               NaN  Arabica       Yidnekachew Dabessa          Ethiopia  ...
# 4               NaN  Arabica                 metad plc          Ethiopia  ...
#
#   Quakers  Color Category Two Defects NA.3        Expiration  \
# 0     0.0  Green       0 full defects  NaN   April 3rd, 2016
# 1     0.0  Green       1 full defects  NaN   April 3rd, 2016
# 2     0.0    NaN       0 full defects  NaN    May 31st, 2011
# 3     0.0  Green       2 full defects  NaN  March 25th, 2016
# 4     0.0  Green       2 full defects  NaN   April 3rd, 2016
#
#                    Certification Body  \
# 0  METAD Agricultural Development plc
# 1  METAD Agricultural Development plc
# 2        Specialty Coffee Association
# 3  METAD Agricultural Development plc
# 4  METAD Agricultural Development plc
#
#                                Certification Address  \
# 0  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 1  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 2        117 W 4th St, Suite 300 Santa Ana, CA 92701
# 3  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 4  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
#
#                                Certification Contact  Unnamed: 51 Notes
# 0  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
# 1  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
# 2                        Chris Buck - (562) 624-4100          NaN   NaN
# 3  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
# 4  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
#
# [5 rows x 53 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0  quality_score  view_certificate_1  view_certificate_2  \
# count  1312.000000    1312.000000                 0.0                 0.0
# mean    655.309451      82.086212                 NaN                 NaN
# std     378.860186       3.675542                 NaN                 NaN
# min       0.000000       0.000000                 NaN                 NaN
# 25%     327.750000      81.170000                 NaN                 NaN
# 50%     655.500000      82.500000                 NaN                 NaN
# 75%     983.250000      83.670000                 NaN                 NaN
# max    1310.000000      90.580000                 NaN                 NaN
#
#        Cupping Protocol and Descriptors  View Green Analysis Details  \
# count                               0.0                          0.0
# mean                                NaN                          NaN
# std                                 NaN                          NaN
# min                                 NaN                          NaN
# 25%                                 NaN                          NaN
# 50%                                 NaN                          NaN
# 75%                                 NaN                          NaN
# max                                 NaN                          NaN
#
#        Request a Sample  Number of Bags        Aroma       Flavor  ...  \
# count               0.0     1312.000000  1312.000000  1312.000000  ...
# mean                NaN      153.770579     7.562614     7.516913  ...
# std                 NaN      129.753818     0.380976     0.402017  ...
# min                 NaN        0.000000     0.000000     0.000000  ...
# 25%                 NaN       14.000000     7.420000     7.330000  ...
# 50%                 NaN      172.500000     7.580000     7.580000  ...
# 75%                 NaN      275.000000     7.750000     7.750000  ...
# max                 NaN     1062.000000     8.750000     8.830000  ...
#
#               Body      Balance   Uniformity    Clean Cup    Sweetness  \
# count  1312.000000  1312.000000  1312.000000  1312.000000  1312.000000
# mean      7.516570     7.516349     9.825899     9.825625     9.895724
# std       0.361512     0.408316     0.621552     0.817449     0.596925
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       7.330000     7.330000    10.000000    10.000000    10.000000
# 50%       7.500000     7.500000    10.000000    10.000000    10.000000
# 75%       7.670000     7.750000    10.000000    10.000000    10.000000
# max       8.580000     8.750000    10.000000    10.000000    10.000000
#
#        Cupper Points  NA.2      Quakers  NA.3  Unnamed: 51
# count    1312.000000   0.0  1311.000000   0.0          0.0
# mean        7.496723   NaN     0.176964   NaN          NaN
# std         0.476228   NaN     0.840276   NaN          NaN
# min         0.000000   NaN     0.000000   NaN          NaN
# 25%         7.250000   NaN     0.000000   NaN          NaN
# 50%         7.500000   NaN     0.000000   NaN          NaN
# 75%         7.750000   NaN     0.000000   NaN          NaN
# max        10.000000   NaN    11.000000   NaN          NaN
#
# [8 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1312 entries, 0 to 1311
# Data columns (total 53 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        1312 non-null   int64
#  1   quality_score                     1312 non-null   float64
#  2   view_certificate_1                0 non-null      float64
#  3   view_certificate_2                0 non-null      float64
#  4   Cupping Protocol and Descriptors  0 non-null      float64
#  5   View Green Analysis Details       0 non-null      float64
#  6   Request a Sample                  0 non-null      float64
#  7   Species                           1312 non-null   object
#  8   Owner                             1305 non-null   object
#  9   Country of Origin                 1311 non-null   object
#  10  Farm Name                         956 non-null    object
#  11  Lot Number                        270 non-null    object
#  12  Mill                              1005 non-null   object
#  13  ICO Number                        1166 non-null   object
#  14  Company                           1102 non-null   object
#  15  Altitude                          1094 non-null   object
#  16  Region                            1256 non-null   object
#  17  Producer                          1082 non-null   object
#  18  Number of Bags                    1312 non-null   int64
#  19  Bag Weight                        1312 non-null   object
#  20  In-Country Partner                1312 non-null   object
#  21  Harvest Year                      1265 non-null   object
#  22  Grading Date                      1312 non-null   object
#  23  Owner.1                           1305 non-null   object
#  24  Variety                           1110 non-null   object
#  25  Status                            1312 non-null   object
#  26  Processing Method                 1159 non-null   object
#  27  NA                                1310 non-null   object
#  28  Aroma                             1312 non-null   float64
#  29  Flavor                            1312 non-null   float64
#  30  Aftertaste                        1312 non-null   float64
#  31  Acidity                           1312 non-null   float64
#  32  Body                              1312 non-null   float64
#  33  Balance                           1312 non-null   float64
#  34  NA.1                              1312 non-null   object
#  35  Uniformity                        1312 non-null   float64
#  36  Clean Cup                         1312 non-null   float64
#  37  Sweetness                         1312 non-null   float64
#  38  Cupper Points                     1312 non-null   float64
#  39  Total Cup Points                  1312 non-null   object
#  40  NA.2                              0 non-null      float64
#  41  Moisture                          1312 non-null   object
#  42  Category One Defects              1312 non-null   object
#  43  Quakers                           1311 non-null   float64
#  44  Color                             1095 non-null   object
#  45  Category Two Defects              1312 non-null   object
#  46  NA.3                              0 non-null      float64
#  47  Expiration                        1312 non-null   object
#  48  Certification Body                1312 non-null   object
#  49  Certification Address             1312 non-null   object
#  50  Certification Contact             1312 non-null   object
#  51  Unnamed: 51                       0 non-null      float64
#  52  Notes                             5 non-null      object
# dtypes: float64(20), int64(2), object(31)
# memory usage: 384.4+ KB

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12, 6)
sns.barplot(x="Owner",y="quality_score",data=df)
# Out:
# <AxesSubplot:xlabel='Owner', ylabel='quality_score'>
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 158 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 151 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 157 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 143 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 136 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 158 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 151 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 157 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 143 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 136 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 156 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12, 6)
sns.barplot(x="Flavor",y="Acidity",data=df)
# Out:
# <AxesSubplot:xlabel='Flavor', ylabel='Acidity'>

# %%
plt.pie(Owner_val[:60],labels=Owner_names[:50],autopct='%1.2f%%'
# Out:
#   File "<ipython-input-8-48cfa1d217cc>", line 1
#     plt.pie(Owner_val[:3],labels=Owner_names[:3],autopct='%1.2f%%'
#                                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.pie(Owner_val[:60],labels=Owner_names[:50],autopct='%1.2f%%'
# Out:
#   File "<ipython-input-9-571d0176d240>", line 1
#     plt.pie(Owner_val[:60],labels=Owner_names[:50],autopct='%1.2f%%'
#                                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
Owner_names=final_df.Owner.value_counts().index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-aee47d54448d> in <module>
# ----> 1 Owner_names=final_df.Owner.value_counts().index
#
# NameError: name 'final_df' is not defined

# %%
Owner_names=df.Owner.value_counts().index

# %%
country_val=df.Country.value_counts().values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-00ad8d8bee01> in <module>
# ----> 1 country_val=df.Country.value_counts().values
#
# ~\Downloads\geop2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Country'

# %%
Owner_val=df.Owner.value_counts().values

# %%
plt.pie(Owner_val[:60],labels=Owner_names[:50],autopct='%1.2f%%'
# Out:
#   File "<ipython-input-14-571d0176d240>", line 1
#     plt.pie(Owner_val[:60],labels=Owner_names[:50],autopct='%1.2f%%'
#                                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.pie(Owner_val[:3],labels=Owner_names[:3],autopct='%1.2f%%'
# Out:
#   File "<ipython-input-15-48cfa1d217cc>", line 1
#     plt.pie(Owner_val[:3],labels=Owner_names[:3],autopct='%1.2f%%'
#                                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.pie(Owner_val[:3],labels=Owner_names[:3],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x382ed48>,
#   <matplotlib.patches.Wedge at 0x383d0e8>,
#   <matplotlib.patches.Wedge at 0x383d3e8>],
#  [Text(-0.260847831443267, 1.0686245406275046, 'Juan Luis Alvarado Romero'),
#   Text(-0.4194677514497408, -1.0168809200165467, 'Racafe & Cia S.C.A'),
#   Text(0.8884060479086436, -0.6486406509303476, 'Exportadora de Cafe Condor S.A')],
#  [Text(-0.14228063533269109, 0.5828861130695479, '57.62%'),
#   Text(-0.22880059169985859, -0.5546623200090255, '22.30%'),
#   Text(0.4845851170410783, -0.3538039914165532, '20.07%')])

# %%
df.corr()
# Out:
#                                   Unnamed: 0  quality_score  \
# Unnamed: 0                          1.000000      -0.674526
# quality_score                      -0.674526       1.000000
# view_certificate_1                       NaN            NaN
# view_certificate_2                       NaN            NaN
# Cupping Protocol and Descriptors         NaN            NaN
# View Green Analysis Details              NaN            NaN
# Request a Sample                         NaN            NaN
# Number of Bags                     -0.071655       0.020231
# Aroma                              -0.628792       0.790684
# Flavor                             -0.732012       0.865454
# Aftertaste                         -0.729368       0.848463
# Acidity                            -0.649855       0.778920
# Body                               -0.593174       0.771429
# Balance                            -0.686571       0.825608
# Uniformity                         -0.317617       0.693991
# Clean Cup                          -0.306318       0.693752
# Sweetness                          -0.201155       0.658838
# Cupper Points                      -0.709254       0.789422
# NA.2                                     NaN            NaN
# Quakers                            -0.015972       0.012977
# NA.3                                     NaN            NaN
# Unnamed: 51                              NaN            NaN
#
#                                   view_certificate_1  view_certificate_2  \
# Unnamed: 0                                       NaN                 NaN
# quality_score                                    NaN                 NaN
# view_certificate_1                               NaN                 NaN
# view_certificate_2                               NaN                 NaN
# Cupping Protocol and Descriptors                 NaN                 NaN
# View Green Analysis Details                      NaN                 NaN
# Request a Sample                                 NaN                 NaN
# Number of Bags                                   NaN                 NaN
# Aroma                                            NaN                 NaN
# Flavor                                           NaN                 NaN
# Aftertaste                                       NaN                 NaN
# Acidity                                          NaN                 NaN
# Body                                             NaN                 NaN
# Balance                                          NaN                 NaN
# Uniformity                                       NaN                 NaN
# Clean Cup                                        NaN                 NaN
# Sweetness                                        NaN                 NaN
# Cupper Points                                    NaN                 NaN
# NA.2                                             NaN                 NaN
# Quakers                                          NaN                 NaN
# NA.3                                             NaN                 NaN
# Unnamed: 51                                      NaN                 NaN
#
#                                   Cupping Protocol and Descriptors  \
# Unnamed: 0                                                     NaN
# quality_score                                                  NaN
# view_certificate_1                                             NaN
# view_certificate_2                                             NaN
# Cupping Protocol and Descriptors                               NaN
# View Green Analysis Details                                    NaN
# Request a Sample                                               NaN
# Number of Bags                                                 NaN
# Aroma                                                          NaN
# Flavor                                                         NaN
# Aftertaste                                                     NaN
# Acidity                                                        NaN
# Body                                                           NaN
# Balance                                                        NaN
# Uniformity                                                     NaN
# Clean Cup                                                      NaN
# Sweetness                                                      NaN
# Cupper Points                                                  NaN
# NA.2                                                           NaN
# Quakers                                                        NaN
# NA.3                                                           NaN
# Unnamed: 51                                                    NaN
#
#                                   View Green Analysis Details  \
# Unnamed: 0                                                NaN
# quality_score                                             NaN
# view_certificate_1                                        NaN
# view_certificate_2                                        NaN
# Cupping Protocol and Descriptors                          NaN
# View Green Analysis Details                               NaN
# Request a Sample                                          NaN
# Number of Bags                                            NaN
# Aroma                                                     NaN
# Flavor                                                    NaN
# Aftertaste                                                NaN
# Acidity                                                   NaN
# Body                                                      NaN
# Balance                                                   NaN
# Uniformity                                                NaN
# Clean Cup                                                 NaN
# Sweetness                                                 NaN
# Cupper Points                                             NaN
# NA.2                                                      NaN
# Quakers                                                   NaN
# NA.3                                                      NaN
# Unnamed: 51                                               NaN
#
#                                   Request a Sample  Number of Bags     Aroma  \
# Unnamed: 0                                     NaN       -0.071655 -0.628792
# quality_score                                  NaN        0.020231  0.790684
# view_certificate_1                             NaN             NaN       NaN
# view_certificate_2                             NaN             NaN       NaN
# Cupping Protocol and Descriptors               NaN             NaN       NaN
# View Green Analysis Details                    NaN             NaN       NaN
# Request a Sample                               NaN             NaN       NaN
# Number of Bags                                 NaN        1.000000 -0.009198
# Aroma                                          NaN       -0.009198  1.000000
# Flavor                                         NaN       -0.004999  0.816464
# Aftertaste                                     NaN       -0.009518  0.778852
# Acidity                                        NaN        0.022684  0.724712
# Body                                           NaN        0.017696  0.700149
# Balance                                        NaN        0.022558  0.720212
# Uniformity                                     NaN        0.033692  0.376458
# Clean Cup                                      NaN        0.037561  0.351413
# Sweetness                                      NaN        0.021359  0.341160
# Cupper Points                                  NaN       -0.010267  0.696130
# NA.2                                           NaN             NaN       NaN
# Quakers                                        NaN        0.136933  0.011338
# NA.3                                           NaN             NaN       NaN
# Unnamed: 51                                    NaN             NaN       NaN
#
#                                     Flavor  ...      Body   Balance  \
# Unnamed: 0                       -0.732012  ... -0.593174 -0.686571
# quality_score                     0.865454  ...  0.771429  0.825608
# view_certificate_1                     NaN  ...       NaN       NaN
# view_certificate_2                     NaN  ...       NaN       NaN
# Cupping Protocol and Descriptors       NaN  ...       NaN       NaN
# View Green Analysis Details            NaN  ...       NaN       NaN
# Request a Sample                       NaN  ...       NaN       NaN
# Number of Bags                   -0.004999  ...  0.017696  0.022558
# Aroma                             0.816464  ...  0.700149  0.720212
# Flavor                            1.000000  ...  0.764511  0.804659
# Aftertaste                        0.895794  ...  0.762312  0.824507
# Acidity                           0.816271  ...  0.732308  0.742410
# Body                              0.764511  ...  1.000000  0.770243
# Balance                           0.804659  ...  0.770243  1.000000
# Uniformity                        0.411258  ...  0.353277  0.406807
# Clean Cup                         0.405982  ...  0.307143  0.385214
# Sweetness                         0.367383  ...  0.341598  0.350170
# Cupper Points                     0.798770  ...  0.674116  0.743702
# NA.2                                   NaN  ...       NaN       NaN
# Quakers                           0.006988  ... -0.003801  0.008671
# NA.3                                   NaN  ...       NaN       NaN
# Unnamed: 51                            NaN  ...       NaN       NaN
#
#                                   Uniformity  Clean Cup  Sweetness  \
# Unnamed: 0                         -0.317617  -0.306318  -0.201155
# quality_score                       0.693991   0.693752   0.658838
# view_certificate_1                       NaN        NaN        NaN
# view_certificate_2                       NaN        NaN        NaN
# Cupping Protocol and Descriptors         NaN        NaN        NaN
# View Green Analysis Details              NaN        NaN        NaN
# Request a Sample                         NaN        NaN        NaN
# Number of Bags                      0.033692   0.037561   0.021359
# Aroma                               0.376458   0.351413   0.341160
# Flavor                              0.411258   0.405982   0.367383
# Aftertaste                          0.392283   0.388679   0.339545
# Acidity                             0.356001   0.297830   0.315458
# Body                                0.353277   0.307143   0.341598
# Balance                             0.406807   0.385214   0.350170
# Uniformity                          1.000000   0.590875   0.630239
# Clean Cup                           0.590875   1.000000   0.593028
# Sweetness                           0.630239   0.593028   1.000000
# Cupper Points                       0.359247   0.364342   0.305525
# NA.2                                     NaN        NaN        NaN
# Quakers                             0.027793   0.026413  -0.004746
# NA.3                                     NaN        NaN        NaN
# Unnamed: 51                              NaN        NaN        NaN
#
#                                   Cupper Points  NA.2   Quakers  NA.3  \
# Unnamed: 0                            -0.709254   NaN -0.015972   NaN
# quality_score                          0.789422   NaN  0.012977   NaN
# view_certificate_1                          NaN   NaN       NaN   NaN
# view_certificate_2                          NaN   NaN       NaN   NaN
# Cupping Protocol and Descriptors            NaN   NaN       NaN   NaN
# View Green Analysis Details                 NaN   NaN       NaN   NaN
# Request a Sample                            NaN   NaN       NaN   NaN
# Number of Bags                        -0.010267   NaN  0.136933   NaN
# Aroma                                  0.696130   NaN  0.011338   NaN
# Flavor                                 0.798770   NaN  0.006988   NaN
# Aftertaste                             0.789226   NaN  0.003264   NaN
# Acidity                                0.701015   NaN -0.012077   NaN
# Body                                   0.674116   NaN -0.003801   NaN
# Balance                                0.743702   NaN  0.008671   NaN
# Uniformity                             0.359247   NaN  0.027793   NaN
# Clean Cup                              0.364342   NaN  0.026413   NaN
# Sweetness                              0.305525   NaN -0.004746   NaN
# Cupper Points                          1.000000   NaN  0.012347   NaN
# NA.2                                        NaN   NaN       NaN   NaN
# Quakers                                0.012347   NaN  1.000000   NaN
# NA.3                                        NaN   NaN       NaN   NaN
# Unnamed: 51                                 NaN   NaN       NaN   NaN
#
#                                   Unnamed: 51
# Unnamed: 0                                NaN
# quality_score                             NaN
# view_certificate_1                        NaN
# view_certificate_2                        NaN
# Cupping Protocol and Descriptors          NaN
# View Green Analysis Details               NaN
# Request a Sample                          NaN
# Number of Bags                            NaN
# Aroma                                     NaN
# Flavor                                    NaN
# Aftertaste                                NaN
# Acidity                                   NaN
# Body                                      NaN
# Balance                                   NaN
# Uniformity                                NaN
# Clean Cup                                 NaN
# Sweetness                                 NaN
# Cupper Points                             NaN
# NA.2                                      NaN
# Quakers                                   NaN
# NA.3                                      NaN
# Unnamed: 51                               NaN
#
# [22 rows x 22 columns]

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# quality_score                          0
# view_certificate_1                  1312
# view_certificate_2                  1312
# Cupping Protocol and Descriptors    1312
# View Green Analysis Details         1312
# Request a Sample                    1312
# Species                                0
# Owner                                  7
# Country of Origin                      1
# Farm Name                            356
# Lot Number                          1042
# Mill                                 307
# ICO Number                           146
# Company                              210
# Altitude                             218
# Region                                56
# Producer                             230
# Number of Bags                         0
# Bag Weight                             0
# In-Country Partner                     0
# Harvest Year                          47
# Grading Date                           0
# Owner.1                                7
# Variety                              202
# Status                                 0
# Processing Method                    153
# NA                                     2
# Aroma                                  0
# Flavor                                 0
# Aftertaste                             0
# Acidity                                0
# Body                                   0
# Balance                                0
# NA.1                                   0
# Uniformity                             0
# Clean Cup                              0
# Sweetness                              0
# Cupper Points                          0
# Total Cup Points                       0
# NA.2                                1312
# Moisture                               0
# Category One Defects                   0
# Quakers                                1
# Color                                217
# Category Two Defects                   0
# NA.3                                1312
# Expiration                             0
# Certification Body                     0
# Certification Address                  0
# Certification Contact                  0
# Unnamed: 51                         1312
# Notes                               1307
# dtype: int64

# %%
df['Flavor'].count()
# Out:
# 1312

# %%
sns.countplot(x="Flavor",data=df,palette=['blue','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Flavor', ylabel='count'>

# %%
sns.jointplot(x='Flavor',y='Acidity',data=df,kind='hex')

# %%
sns.distplot(df['Flavor'])
# Out:
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Flavor', ylabel='Density'>

# %%
sns.countplot('Flavor',data=df)
# Out:
# <AxesSubplot:xlabel='Flavor', ylabel='count'>

# %%
sns.boxplot('Flavor','Acidity', data=df)
# Out:
# C:\Users\DGVC\Downloads\geop2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Flavor', ylabel='Acidity'>

# %%
sns.violinplot(x="Flavor", y="Acidity", data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Flavor', ylabel='Acidity'>
